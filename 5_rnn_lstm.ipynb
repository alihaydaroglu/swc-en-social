# %%
import numpy as n
from matplotlib import pyplot as plt
import os
import numpy.lib.recfunctions as rfn
import copy

from sklearn.metrics import confusion_matrix

import torch
from torch import nn

# %%
import time

# %% [markdown]
# ## Functions
# #### Load data files
# `data_root` should contain the root directory of the folder downloaded from Dropbox.

# %%
def load_data(data_root, dlc_dir, ann_dir, verbose=False):
    
    dlc_path = os.path.join(data_root, dlc_dir)
    ann_path = os.path.join(data_root, ann_dir)
    all_data = {}
    if verbose: print("Loading files: ")
    for f_name in os.listdir(dlc_path):
        if f_name[-3:] != 'npy':
            continue

        dlc_file=os.path.join(dlc_path, f_name)
        ann_file=os.path.join(ann_path, 'Annotated_' + f_name)
        if verbose: print("\t" + f_name + "\n\tAnnotated_" + f_name)
        data_dlc = n.load(dlc_file)
        data_ann = n.load(ann_file)
        labels = data_dlc[0]
        dtype = [('t', n.int), ('ann', 'U30')]
        i = 0
        for label in data_dlc[0]:
            i += 1
            coord = 'x' if i % 2 == 0 else 'y'
            dtype += [(label + '_' + coord , n.float32 )]

        data_concat = n.concatenate((data_ann, data_dlc[1:]),axis=1)
        data = n.array(n.zeros(data_concat.shape[0]), dtype = dtype)
        for i in range(data_concat.shape[1]):
            data[dtype[i][0]] = data_concat[:, i]
        all_data[f_name[:-4]] = data
    return all_data

# %% [markdown]
# #### Velocities

# %%
def dot(a, b):
    return n.sum(a * b, axis=-1)

def mag(a):
    return n.sqrt(n.sum(a*a, axis=-1))

def get_angle(a, b):
    cosab = dot(a, b) / (mag(a) * mag(b)) # cosine of angle between vectors
    angle = n.arccos(cosab) # what you currently have (absolute angle)

    b_t = b[:,[1,0]] * [1, -1] # perpendicular of b

    is_cc = dot(a, b_t) < 0

    # invert the angles for counter-clockwise rotations
    angle[is_cc] = 2*n.pi - angle[is_cc]
    return 360 - n.rad2deg(angle)

# %%
def calculate_velocity(trial):
    names = []; dtypes = []; datas = []
    velocities_calculated = []
    for label in trial.dtype.names:
        if label[-2:] in ['_x', '_y']:
            names.append(label+'_vel')  
            dtypes += [n.float]
            datas += [n.zeros(trial.shape[0])]
            velocities_calculated.append(label)
    trial = rfn.append_fields(trial, names, datas, dtypes)
    trial = n.array(trial, trial.dtype)
    for label in velocities_calculated:
        vel = n.gradient(trial[label])
        trial[label + '_vel'] = vel
    return trial
def normalize_trial(trial, feature_labels, nan = -10000):
    ref_x = trial[feature_labels[1]].copy()
    ref_y = trial[feature_labels[0]].copy()
    for i,label in enumerate(feature_labels):
        if label[-1] == 'y':
    #         print('y-pre:',n.nanmax(features[:,i]))
            trial[label] -= ref_y
    #         print('y-post:', n.nanmax(features[:,i]))
        elif label[-1] == 'x':
    #         print('x-pre:',n.nanmax(features[:,i]))
            trial[label] -= ref_x
    #         print('x-post:', n.nanmax(features[:,i]))

    mouse_1_pos_labels = []
    mouse_2_pos_labels = []
    mouse_1_vel_labels = []
    mouse_2_vel_labels = []
    for label in feature_labels:
        if label[-3:] == 'vel':
            if label[-7] == '1':
                mouse_1_vel_labels.append(label)
            else:
                mouse_2_vel_labels.append(label)
        else:
            if label[-3] == '1':
                mouse_1_pos_labels.append(label)
            else:
                mouse_2_pos_labels.append(label)


    mouse_1_pos = n.zeros((len(mouse_1_pos_labels),len(trial)))
    for i,l in enumerate(mouse_1_pos_labels): mouse_1_pos[i]=trial[l]
    mouse_2_pos = n.zeros((len(mouse_2_pos_labels),len(trial)))
    for i,l in enumerate(mouse_2_pos_labels): mouse_2_pos[i]=trial[l]
    mouse_1_vel = n.zeros((len(mouse_1_vel_labels),len(trial)))
    for i,l in enumerate(mouse_1_vel_labels): mouse_1_vel[i]=trial[l]
    mouse_2_vel = n.zeros((len(mouse_2_vel_labels),len(trial)))
    for i,l in enumerate(mouse_2_vel_labels): mouse_2_vel[i]=trial[l]
    # TODO how to normalize??
    trial_data = n.concatenate([mouse_1_pos, mouse_2_pos, mouse_1_vel, mouse_2_vel])
    if nan is not None:
        trial_data = n.nan_to_num(trial_data, nan=nan)
    
    trial_labels = n.concatenate([mouse_1_pos_labels, mouse_2_pos_labels, mouse_1_vel_labels, mouse_2_vel_labels])
    
    return trial_data, trial_labels

# %% [markdown]
# ## Separate train, test and val sets

# %%
def split_sets(features_all,targets_all, chunk_size=500, splits= (0.7, 0.2, 0.1), separate_vid_idx = None):
    data_len = features_all.shape[0]
    num_chunks = data_len // chunk_size
    chunk_list = n.random.choice(range(num_chunks), size=num_chunks, replace=False)

    test_chunk_idx_bound = splits[0]*num_chunks
    val_chunk_idx_bound = (splits[0]+splits[1])*num_chunks

    features_train = []
    features_test = []
    features_val = []
    targets_train = []
    targets_test = []
    targets_val = []
    
    if separate_vid_idx is not None:
        targets_separate = []
        features_separate = []

    for i in range(num_chunks):
        curr_chunk_idx = chunk_list[i]*chunk_size
        curr_chunk = features_all[curr_chunk_idx:curr_chunk_idx+chunk_size,:]
        curr_chunk_t = targets_all[curr_chunk_idx:curr_chunk_idx+chunk_size]
#         print(curr_chunk_idx)
        if separate_vid_idx is not None and curr_chunk_idx+chunk_size > separate_vid_idx[0] and curr_chunk_idx < separate_vid_idx[1]:
#                 print(curr_chunk_idx, separate_vid_idx[0])
#                 print(curr_chunk_idx+chunk_size, separate_vid_idx[1])
                targets_separate.append(curr_chunk_t)
                features_separate.append(curr_chunk)
        elif i < test_chunk_idx_bound:
#             print("train!!")
            features_train.append(curr_chunk)
            targets_train.append(curr_chunk_t)
        elif i < val_chunk_idx_bound:
#             print('test')
            features_test.append(curr_chunk)
            targets_test.append(curr_chunk_t)
        else:
#             print('val')
            features_val.append(curr_chunk)
            targets_val.append(curr_chunk_t)

#     print(len(features_separate))
#     print(len(targets_separate))
    features_train = n.concatenate(features_train, axis=0)
    features_test = n.concatenate(features_test, axis=0)
    features_val = n.concatenate(features_val, axis=0)
    
    targets_val = n.concatenate(targets_val)
    targets_test = n.concatenate(targets_test)
    targets_train = n.concatenate(targets_train)
    
    if separate_vid_idx is None:
        return features_train, features_test, features_val, targets_train, targets_test, targets_val
    else:
        features_separate = n.concatenate(features_separate, axis=0)
        targets_separate = n.concatenate(targets_separate)
        return features_train, features_test, features_val, features_separate,\
                targets_train, targets_test, targets_val, targets_separate

def str_to_int(targets, mapping = None):
    categories = n.unique(targets)
    N_categories = len(categories)
    if mapping is None:
        mapping = {}
        i = 0
        for c in categories:
            mapping[c] = i
            i += 1
    targets_int = n.array([mapping[s] for s in targets], dtype=int)
    
    return targets_int, mapping

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

class MLP():
    def __init__(self, architecture):
        self.architecture = architecture
        
        self.D_in = self.architecture['D_in']
        self.D_out = self.architecture['D_out']
        self.hidden_dims = self.architecture['hidden_dims']
        
        self.layers = []
        prev_dim = self.architecture['D_in']
        for dim in self.architecture['hidden_dims']:
            self.layers += [torch.nn.Linear(prev_dim, dim),
                           torch.nn.ReLU()]
            prev_dim = dim
        self.layers += [torch.nn.Linear(prev_dim, self.D_out)]
        self.model = nn.Sequential(*self.layers)
        
        self.trackers = {}

    def init_weights(self):
        self.model.apply(init_weights)
   
    def start_trackers(self,track, reset_trackers=True):
        if reset_trackers: self.trackers = {}
        for t in track:
            self.trackers[t] = []
    
    def track(self):
        for variable in self.trackers.keys():
            self.trackers[variable].append(copy.deepcopy(getattr(self, variable)))
        
    def learn(self,learning, training_set, test_set, reset_trackers=True, verbose=True):
        
        #self.init_weights()
        
        # set up variables
        N_batch = learning['N_batch']
        N_epochs = learning['N_epochs']
        loss_fn = learning['loss_fn']
        print_interval = learning['print_interval']
        track = learning['track']
        learning_rate = learning['learning_rate']
        
        self.learning = learning
        
        optimizer = learning['optimizer'](self.model.parameters(), learning_rate)
        self.start_trackers(track, reset_trackers)
        
        # load data
        x_train, y_train = training_set
        x_test, y_test = test_set

        N_training = len(y_train)
        N_test = len(y_test)
    
        self.t = 0
        tic = time.time()
        end = False
        for self.epoch_idx in range(N_epochs):
            if verbose: print("### EPOCH {:2d} ###".format(self.epoch_idx))
                
            # randomize batches
            indices = n.random.choice(range(N_training), N_training, False)
            num_batches = len(indices) // N_batch + 1

            for self.batch_idx in range(num_batches):
                # load batch
                b_idx = self.batch_idx
                x_train_batch = x_train[indices[b_idx*N_batch :(b_idx+1)*N_batch]]
                y_train_batch = y_train[indices[b_idx*N_batch : (b_idx+1)*N_batch]]

                
                # predict, loss and learn
                y_train_batch_pred = self.model(x_train_batch)
                loss = loss_fn(y_train_batch_pred, y_train_batch)
                self.train_loss = loss.item()
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                self.t += 1

                if self.batch_idx % print_interval == 0:
                    
#                     y_train_pred = self.model(x_train)
#                     self.train_loss = loss_fn(y_train_pred, y_train).item()
#                     pred_labels = n.argmax(y_train_pred.detach().numpy(),axis=1)
#                     true_labels = y_train.detach().numpy()
#                     correct_preds = n.array(pred_labels == true_labels, n.int)
                    self.train_frac_correct = 0# n.mean(correct_preds)
                    
                    y_test_pred = self.model(x_test)
                    self.test_loss = loss_fn(y_test_pred, y_test).item()
                    pred_labels = n.argmax(y_test_pred.detach().numpy(),axis=1)
                    true_labels = y_test.detach().numpy()
                    correct_preds = n.array(pred_labels == true_labels, n.int)
                    self.test_frac_correct = n.mean(correct_preds)

                    toc = time.time()
                    delta = toc - tic
                    tic = toc
                    print("Time: {:4.2f}, Batch {:3d}, Train Loss (for batch): {:4.2f}, Test Loss: {:4.2f}, Test Correct Frac: {:.3f}".format(\
                                       delta, self.batch_idx, self.train_loss, self.test_loss, self.test_frac_correct))
            
                    self.track()

# %%
def plot_net_results(net, x_test, y_test):
    plt.plot(net.trackers['t'],net.trackers['train_loss'], label='train')
    plt.plot(net.trackers['t'],net.trackers['test_loss'], label='test')
    plt.title("Cross Entropy Loss through training")
    plt.legend()
    plt.ylim(0,10)
    plt.show()
    
    plt.plot(net.trackers['t'], net.trackers['test_frac_correct'])
    plt.title("Fraction of correct labels on test set through training")
    plt.ylim(0.5,1)
    plt.show()
    
    max_perf_ind = n.argmax(net.trackers['test_frac_correct'])
    min_loss_ind = n.argmin(net.trackers['test_loss'])
    max_perf_model = net.trackers['model'][max_perf_ind]
    
    prediction_test = max_perf_model(x_test)
    pred = n.argmax(prediction_test.detach().numpy(),axis=1)
    true = y_test.detach().numpy()
    confmat = confusion_matrix(true, pred, normalize='true')
    f, ax = plt.subplots(figsize=(10,10))
    m = ax.matshow(confmat, cmap='Blues', vmin=0,  vmax=1)
    ax.set_xlabel("Predicted Label")
    ax.set_ylabel("True Label")
    ax.set_xticks(list(range(len(categories))))
    ax.set_xticklabels(categories, rotation=45)
    ax.set_yticks(list(range(len(categories))))
    ax.set_yticklabels(categories, rotation=45)
    f.colorbar(m)
    
    plt.show()

# %% [markdown]
# ## Run

# %%
# Load data into a structured array
data_root = '/mnt/d/Ali/Google Drive/SWC/Experimental Neuroscience/social and affective systems/rat_social_beh'
dlc_dir = 'postprocessedXYCoordinates'
ann_dir = 'manualannotations'
all_data = load_data(data_root, dlc_dir, ann_dir)

# Choose which position labels we care about
feature_labels = all_data['Female1'].dtype.names[2:]

# Calculate velocity and preprocess/scale/normalize data
trial_keys = list(all_data.keys())
datas = []
for key in trial_keys:
    datas.append(normalize_trial(all_data[key], feature_labels)[0])
features_all = n.concatenate(datas, axis=1).T

# Format category labels
targets_all = n.concatenate([all_data[key]['ann'] for key in trial_keys]).T
targets_int, target_map = str_to_int(targets_all)
categories = target_map.keys()
N_categories = len(categories)

# %%
n_window = 100
n_stride = 10
datapoints = []
labels = []

trial_bounds = []

trial_idx = 0
idx = 0
for data in datas:  
    trial_bounds.append(idx)
    for i in range(int(data.shape[1]/n_stride)):
        if (i*n_stride + n_window) < data.shape[1]:
            datapoints.append(data[:,i*n_stride : i*n_stride + n_window])
            labels.append(all_data[trial_keys[trial_idx]]['ann'][i*n_stride : i*n_stride + n_window])
            idx += 1
    trial_idx += 1

# %%
Xs = n.stack(datapoints)
Ys = n.stack(labels)

# %%
Xs.shape
# Out:
# (20994, 40, 100)

# %%
Ys.shape
# Out:
# (20994, 100)

# %%
trial_bounds
# Out:
# [0, 3017, 5646, 9177, 11629, 14618, 17753]

# %%
features_all.shape
# Out:
# (210617, 40)

# %%
len(labels[0])
# Out:
# 100

# %%
datapoints[0].shape
# Out:
# (40, 100)

# %%
datas[0].shape
# Out:
# (40, 30270)

# %%
features_all.shape
# Out:
# (210617, 40)

# %%
x = 0
bounds = []
for key in all_data:
    bounds.append((x, x+all_data[key].shape[0]))
    x += all_data[key].shape[0]

# %%
split_params = [(bounds[i], (0.98,0.01,0.01)) for i in range(0,len(bounds),2)]

n_layerss = [5, 8]
layer_widths = [100, 300, 500]

learning_rates = [1e-4, 1e-3]
N_batchs = [4,16,64]

# %%
ft_tr, ft_ts, ft_vl,ft_sp, tg_tr, tg_ts, tg_vl, tg_sp = split_sets(features_all, targets_int, splits=(0.95, 0.02, 0.03),separate_vid_idx=bounds[1])

# %%
ft_tr.shape
# Out:
# (175000, 40)

# %%
default_architecture = {
    'D_in' : features_all.shape[1],
    'D_out' : N_categories,
    'hidden_dims' : [300, 300, 300],
    'act_func' : torch.nn.ReLU,
}

default_learning = {
    'N_batch' : 16,
    'N_epochs' : 3,
    'optimizer' : torch.optim.Adam,
    'loss_fn' : torch.nn.CrossEntropyLoss(),
    'print_interval' : 200,  
    'learning_rate' : 1e-4,
    'track' : ['test_loss', 'batch_idx', 'epoch_idx','t', 'train_loss','test_frac_correct','train_frac_correct']
}

result_nets = []

for N_batch in N_batchs:
    result_nets.append([])
    for learning_rate in learning_rates:
        result_nets[-1].append([])
        for n_layers in n_layerss:
            result_nets[-1][-1].append([])
            for layer_width in layer_widths:
                descriptor = "Net with {:2d} layers, {:3d} wide. Using learning rate of {:.6f} and {:2d} batches".format(n_layers, layer_width, learning_rate, N_batch)
                architecture_n = copy.deepcopy(default_architecture)
                learning_n = copy.deepcopy(default_learning)
                architecture_n['hidden_dims'] = [layer_width] * n_layers
                learning_n['N_batch'] = N_batch
                learning_n['learning_rate'] = learning_rate

                n.random.seed(0)
                torch.manual_seed(0)

                # split features and targets (ft/tg) into training, test and validation sets
                ft_tr, ft_ts, ft_vl,ft_sp, tg_tr, tg_ts, tg_vl, tg_sp = split_sets(features_all, targets_int, splits=(0.95, 0.02, 0.03),separate_vid_idx=(0,30270))


                ft_tr = torch.tensor(ft_tr).float()
                ft_ts = torch.tensor(ft_ts).float()
                ft_vl = torch.tensor(ft_vl).float()
                ft_sp = torch.tensor(ft_sp).float()
                tg_tr = torch.tensor(tg_tr).long()
                tg_ts = torch.tensor(tg_ts).long()
                tg_vl = torch.tensor(tg_vl).long()
                tg_sp = torch.tensor(tg_sp).long()

                net = MLP(architecture_n)
                print("\n\n",descriptor)
                net.learn(learning_n, (ft_tr,tg_tr), (ft_sp, tg_sp))
                print("\n\n",descriptor)
#                 plot_net_results(net, ft_sp, tg_sp)
                result_nets[-1][-1][-1].append(copy.deepcopy(net))
# Out:
#  Net with  5 layers, 100 wide. Using learning rate of 0.000100 and  4 batches
# ### EPOCH  0 ###
# Time: 0.09, Batch   0, Train Loss (for batch): 72.26, Test Loss: 66.30, Test Correct Frac: 0.051
# Time: 0.48, Batch 200, Train Loss (for batch): 0.00, Test Loss: 0.84, Test Correct Frac: 0.667
# Time: 0.47, Batch 400, Train Loss (for batch): 0.31, Test Loss: 0.75, Test Correct Frac: 0.718
# Time: 0.49, Batch 600, Train Loss (for batch): 0.45, Test Loss: 0.65, Test Correct Frac: 0.773
# Time: 0.47, Batch 800, Train Loss (for batch): 0.28, Test Loss: 0.72, Test Correct Frac: 0.735
# Time: 0.49, Batch 1000, Train Loss (for batch): 1.05, Test Loss: 0.67, Test Correct Frac: 0.769
# Time: 0.48, Batch 1200, Train Loss (for batch): 0.60, Test Loss: 0.68, Test Correct Frac: 0.750
# Time: 0.49, Batch 1400, Train Loss (for batch): 0.00, Test Loss: 0.62, Test Correct Frac: 0.764
# Time: 0.49, Batch 1600, Train Loss (for batch): 0.12, Test Loss: 0.60, Test Correct Frac: 0.793
# Time: 0.49, Batch 1800, Train Loss (for batch): 0.00, Test Loss: 0.52, Test Correct Frac: 0.837
# Time: 0.49, Batch 2000, Train Loss (for batch): 0.01, Test Loss: 0.56, Test Correct Frac: 0.809
# Time: 0.50, Batch 2200, Train Loss (for batch): 0.45, Test Loss: 0.58, Test Correct Frac: 0.798
# Time: 0.49, Batch 2400, Train Loss (for batch): 0.00, Test Loss: 0.55, Test Correct Frac: 0.804
# Time: 0.49, Batch 2600, Train Loss (for batch): 0.00, Test Loss: 0.56, Test Correct Frac: 0.820
# Time: 0.49, Batch 2800, Train Loss (for batch): 0.04, Test Loss: 0.59, Test Correct Frac: 0.787
# Time: 0.49, Batch 3000, Train Loss (for batch): 0.00, Test Loss: 0.57, Test Correct Frac: 0.793
# Time: 0.50, Batch 3200, Train Loss (for batch): 0.31, Test Loss: 0.54, Test Correct Frac: 0.814
# Time: 0.49, Batch 3400, Train Loss (for batch): 0.01, Test Loss: 0.51, Test Correct Frac: 0.827
# Time: 0.49, Batch 3600, Train Loss (for batch): 0.27, Test Loss: 0.71, Test Correct Frac: 0.772
# Time: 0.49, Batch 3800, Train Loss (for batch): 0.00, Test Loss: 0.72, Test Correct Frac: 0.774
# Time: 0.49, Batch 4000, Train Loss (for batch): 0.85, Test Loss: 0.47, Test Correct Frac: 0.830
# Time: 0.50, Batch 4200, Train Loss (for batch): 0.00, Test Loss: 0.52, Test Correct Frac: 0.818
# Time: 0.50, Batch 4400, Train Loss (for batch): 1.04, Test Loss: 0.49, Test Correct Frac: 0.825
# Time: 0.50, Batch 4600, Train Loss (for batch): 0.69, Test Loss: 0.53, Test Correct Frac: 0.812
# Time: 0.60, Batch 4800, Train Loss (for batch): 0.00, Test Loss: 0.61, Test Correct Frac: 0.801
# Time: 0.58, Batch 5000, Train Loss (for batch): 0.17, Test Loss: 0.62, Test Correct Frac: 0.782
# Time: 0.49, Batch 5200, Train Loss (for batch): 0.33, Test Loss: 0.49, Test Correct Frac: 0.832
# Time: 0.49, Batch 5400, Train Loss (for batch): 0.00, Test Loss: 0.53, Test Correct Frac: 0.799
# Time: 0.49, Batch 5600, Train Loss (for batch): 0.08, Test Loss: 0.49, Test Correct Frac: 0.832
# Time: 0.50, Batch 5800, Train Loss (for batch): 0.36, Test Loss: 0.52, Test Correct Frac: 0.798
# Time: 0.49, Batch 6000, Train Loss (for batch): 0.00, Test Loss: 0.56, Test Correct Frac: 0.792
# Time: 0.49, Batch 6200, Train Loss (for batch): 0.19, Test Loss: 0.50, Test Correct Frac: 0.825
# Time: 0.48, Batch 6400, Train Loss (for batch): 0.00, Test Loss: 0.48, Test Correct Frac: 0.832
# Time: 0.49, Batch 6600, Train Loss (for batch): 0.00, Test Loss: 0.59, Test Correct Frac: 0.821
# Time: 0.53, Batch 6800, Train Loss (for batch): 0.00, Test Loss: 0.59, Test Correct Frac: 0.811
# Time: 0.49, Batch 7000, Train Loss (for batch): 0.68, Test Loss: 0.44, Test Correct Frac: 0.838
# Time: 0.49, Batch 7200, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.858
# Time: 0.49, Batch 7400, Train Loss (for batch): 0.16, Test Loss: 0.49, Test Correct Frac: 0.839
# Time: 0.51, Batch 7600, Train Loss (for batch): 0.00, Test Loss: 0.50, Test Correct Frac: 0.847
# Time: 0.50, Batch 7800, Train Loss (for batch): 0.45, Test Loss: 0.47, Test Correct Frac: 0.844
# Time: 0.49, Batch 8000, Train Loss (for batch): 0.14, Test Loss: 0.42, Test Correct Frac: 0.853
# Time: 0.50, Batch 8200, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.860
# Time: 0.49, Batch 8400, Train Loss (for batch): 0.00, Test Loss: 0.49, Test Correct Frac: 0.826
# Time: 0.49, Batch 8600, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.867
# Time: 0.50, Batch 8800, Train Loss (for batch): 0.00, Test Loss: 0.51, Test Correct Frac: 0.830
# Time: 0.56, Batch 9000, Train Loss (for batch): 0.01, Test Loss: 0.43, Test Correct Frac: 0.863
# Time: 0.48, Batch 9200, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.865
# Time: 0.48, Batch 9400, Train Loss (for batch): 0.24, Test Loss: 0.45, Test Correct Frac: 0.842
# Time: 0.49, Batch 9600, Train Loss (for batch): 3.42, Test Loss: 0.40, Test Correct Frac: 0.865
# Time: 0.49, Batch 9800, Train Loss (for batch): 1.65, Test Loss: 0.63, Test Correct Frac: 0.781
# Time: 0.49, Batch 10000, Train Loss (for batch): 0.60, Test Loss: 0.42, Test Correct Frac: 0.863
# Time: 0.57, Batch 10200, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.862
# Time: 0.52, Batch 10400, Train Loss (for batch): 0.01, Test Loss: 0.39, Test Correct Frac: 0.862
# Time: 0.56, Batch 10600, Train Loss (for batch): 0.20, Test Loss: 0.46, Test Correct Frac: 0.845
# Time: 0.49, Batch 10800, Train Loss (for batch): 0.00, Test Loss: 0.48, Test Correct Frac: 0.842
# Time: 0.49, Batch 11000, Train Loss (for batch): 0.64, Test Loss: 0.41, Test Correct Frac: 0.860
# Time: 0.58, Batch 11200, Train Loss (for batch): 0.27, Test Loss: 0.47, Test Correct Frac: 0.837
# Time: 0.70, Batch 11400, Train Loss (for batch): 0.19, Test Loss: 0.45, Test Correct Frac: 0.859
# Time: 0.57, Batch 11600, Train Loss (for batch): 0.83, Test Loss: 0.53, Test Correct Frac: 0.845
# Time: 0.49, Batch 11800, Train Loss (for batch): 0.32, Test Loss: 0.45, Test Correct Frac: 0.856
# Time: 0.50, Batch 12000, Train Loss (for batch): 0.00, Test Loss: 0.54, Test Correct Frac: 0.807
# Time: 0.49, Batch 12200, Train Loss (for batch): 0.03, Test Loss: 0.40, Test Correct Frac: 0.862
# Time: 0.50, Batch 12400, Train Loss (for batch): 0.18, Test Loss: 0.42, Test Correct Frac: 0.854
# Time: 0.50, Batch 12600, Train Loss (for batch): 0.00, Test Loss: 0.49, Test Correct Frac: 0.824
# Time: 0.49, Batch 12800, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.848
# Time: 0.49, Batch 13000, Train Loss (for batch): 0.24, Test Loss: 0.40, Test Correct Frac: 0.856
# Time: 0.49, Batch 13200, Train Loss (for batch): 0.07, Test Loss: 0.46, Test Correct Frac: 0.859
# Time: 0.49, Batch 13400, Train Loss (for batch): 0.13, Test Loss: 0.44, Test Correct Frac: 0.852
# Time: 0.48, Batch 13600, Train Loss (for batch): 0.50, Test Loss: 0.40, Test Correct Frac: 0.866
# Time: 0.50, Batch 13800, Train Loss (for batch): 0.05, Test Loss: 0.38, Test Correct Frac: 0.873
# Time: 0.49, Batch 14000, Train Loss (for batch): 0.03, Test Loss: 0.49, Test Correct Frac: 0.818
# Time: 0.49, Batch 14200, Train Loss (for batch): 0.10, Test Loss: 0.39, Test Correct Frac: 0.862
# Time: 0.49, Batch 14400, Train Loss (for batch): 0.19, Test Loss: 0.43, Test Correct Frac: 0.845
# Time: 0.49, Batch 14600, Train Loss (for batch): 0.14, Test Loss: 0.39, Test Correct Frac: 0.863
# Time: 0.49, Batch 14800, Train Loss (for batch): 0.00, Test Loss: 0.49, Test Correct Frac: 0.827
# Time: 0.49, Batch 15000, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.846
# Time: 0.50, Batch 15200, Train Loss (for batch): 0.93, Test Loss: 0.47, Test Correct Frac: 0.827
# Time: 0.49, Batch 15400, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.862
# Time: 0.48, Batch 15600, Train Loss (for batch): 0.20, Test Loss: 0.39, Test Correct Frac: 0.873
# Time: 0.49, Batch 15800, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.869
# Time: 0.49, Batch 16000, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.846
# Time: 0.49, Batch 16200, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.865
# Time: 0.49, Batch 16400, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.864
# Time: 0.50, Batch 16600, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.857
# Time: 0.49, Batch 16800, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.855
# Time: 0.49, Batch 17000, Train Loss (for batch): 0.04, Test Loss: 0.48, Test Correct Frac: 0.836
# Time: 0.49, Batch 17200, Train Loss (for batch): 0.02, Test Loss: 0.47, Test Correct Frac: 0.850
# Time: 0.48, Batch 17400, Train Loss (for batch): 0.46, Test Loss: 0.39, Test Correct Frac: 0.869
# Time: 0.48, Batch 17600, Train Loss (for batch): 0.04, Test Loss: 0.48, Test Correct Frac: 0.826
# Time: 0.52, Batch 17800, Train Loss (for batch): 0.04, Test Loss: 0.47, Test Correct Frac: 0.833
# Time: 0.49, Batch 18000, Train Loss (for batch): 0.20, Test Loss: 0.46, Test Correct Frac: 0.837
# Time: 0.50, Batch 18200, Train Loss (for batch): 0.00, Test Loss: 0.48, Test Correct Frac: 0.840
# Time: 0.50, Batch 18400, Train Loss (for batch): 0.06, Test Loss: 0.40, Test Correct Frac: 0.864
# Time: 0.50, Batch 18600, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.850
# Time: 0.49, Batch 18800, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.862
# Time: 0.49, Batch 19000, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.836
# Time: 0.49, Batch 19200, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.845
# Time: 0.49, Batch 19400, Train Loss (for batch): 0.02, Test Loss: 0.41, Test Correct Frac: 0.847
# Time: 0.48, Batch 19600, Train Loss (for batch): 0.01, Test Loss: 0.41, Test Correct Frac: 0.855
# Time: 0.49, Batch 19800, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.856
# Time: 0.49, Batch 20000, Train Loss (for batch): 0.03, Test Loss: 0.41, Test Correct Frac: 0.860
# Time: 0.48, Batch 20200, Train Loss (for batch): 0.00, Test Loss: 0.50, Test Correct Frac: 0.836
# Time: 0.48, Batch 20400, Train Loss (for batch): 0.00, Test Loss: 0.49, Test Correct Frac: 0.825
# Time: 0.57, Batch 20600, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.834
# Time: 0.49, Batch 20800, Train Loss (for batch): 0.08, Test Loss: 0.45, Test Correct Frac: 0.841
# Time: 0.48, Batch 21000, Train Loss (for batch): 0.01, Test Loss: 0.51, Test Correct Frac: 0.823
# Time: 0.48, Batch 21200, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.855
# Time: 0.49, Batch 21400, Train Loss (for batch): 1.18, Test Loss: 0.51, Test Correct Frac: 0.827
# Time: 0.50, Batch 21600, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.846
# Time: 0.61, Batch 21800, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.848
# Time: 0.63, Batch 22000, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.852
# Time: 0.49, Batch 22200, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.862
# Time: 0.49, Batch 22400, Train Loss (for batch): 0.01, Test Loss: 0.39, Test Correct Frac: 0.865
# Time: 0.49, Batch 22600, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.869
# Time: 0.48, Batch 22800, Train Loss (for batch): 2.60, Test Loss: 0.53, Test Correct Frac: 0.844
# Time: 0.49, Batch 23000, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.842
# Time: 0.48, Batch 23200, Train Loss (for batch): 0.01, Test Loss: 0.41, Test Correct Frac: 0.870
# Time: 0.48, Batch 23400, Train Loss (for batch): 0.00, Test Loss: 0.48, Test Correct Frac: 0.841
# Time: 0.49, Batch 23600, Train Loss (for batch): 0.01, Test Loss: 0.47, Test Correct Frac: 0.847
# Time: 0.49, Batch 23800, Train Loss (for batch): 0.19, Test Loss: 0.55, Test Correct Frac: 0.813
# Time: 0.50, Batch 24000, Train Loss (for batch): 0.00, Test Loss: 0.49, Test Correct Frac: 0.860
# Time: 0.49, Batch 24200, Train Loss (for batch): 0.01, Test Loss: 0.47, Test Correct Frac: 0.860
# Time: 0.49, Batch 24400, Train Loss (for batch): 0.31, Test Loss: 0.48, Test Correct Frac: 0.853
# Time: 0.49, Batch 24600, Train Loss (for batch): 0.01, Test Loss: 0.44, Test Correct Frac: 0.866
# Time: 0.48, Batch 24800, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.859
# Time: 0.48, Batch 25000, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.875
# Time: 0.48, Batch 25200, Train Loss (for batch): 0.00, Test Loss: 0.50, Test Correct Frac: 0.844
# Time: 0.48, Batch 25400, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.857
# Time: 0.48, Batch 25600, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.857
# Time: 0.49, Batch 25800, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.854
# Time: 0.49, Batch 26000, Train Loss (for batch): 0.03, Test Loss: 0.39, Test Correct Frac: 0.869
# Time: 0.48, Batch 26200, Train Loss (for batch): 0.24, Test Loss: 0.42, Test Correct Frac: 0.856
# Time: 0.49, Batch 26400, Train Loss (for batch): 0.21, Test Loss: 0.49, Test Correct Frac: 0.831
# Time: 0.48, Batch 26600, Train Loss (for batch): 0.10, Test Loss: 0.43, Test Correct Frac: 0.859
# Time: 0.49, Batch 26800, Train Loss (for batch): 0.08, Test Loss: 0.48, Test Correct Frac: 0.849
# Time: 0.48, Batch 27000, Train Loss (for batch): 0.72, Test Loss: 0.44, Test Correct Frac: 0.846
# Time: 0.48, Batch 27200, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.864
# Time: 0.48, Batch 27400, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.880
# Time: 0.48, Batch 27600, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.881
# Time: 0.48, Batch 27800, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.857
# Time: 0.48, Batch 28000, Train Loss (for batch): 0.22, Test Loss: 0.40, Test Correct Frac: 0.870
# Time: 0.48, Batch 28200, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.859
# Time: 0.48, Batch 28400, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.849
# Time: 0.48, Batch 28600, Train Loss (for batch): 0.10, Test Loss: 0.40, Test Correct Frac: 0.873
# Time: 0.48, Batch 28800, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.868
# Time: 0.48, Batch 29000, Train Loss (for batch): 0.03, Test Loss: 0.42, Test Correct Frac: 0.844
# Time: 0.48, Batch 29200, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.864
# Time: 0.48, Batch 29400, Train Loss (for batch): 0.21, Test Loss: 0.42, Test Correct Frac: 0.856
# Time: 0.49, Batch 29600, Train Loss (for batch): 0.64, Test Loss: 0.41, Test Correct Frac: 0.864
# Time: 0.48, Batch 29800, Train Loss (for batch): 0.22, Test Loss: 0.38, Test Correct Frac: 0.871
# Time: 0.49, Batch 30000, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.865
# Time: 0.48, Batch 30200, Train Loss (for batch): 0.43, Test Loss: 0.36, Test Correct Frac: 0.884
# Time: 0.48, Batch 30400, Train Loss (for batch): 0.05, Test Loss: 0.37, Test Correct Frac: 0.878
# Time: 0.49, Batch 30600, Train Loss (for batch): 0.19, Test Loss: 0.38, Test Correct Frac: 0.872
# Time: 0.49, Batch 30800, Train Loss (for batch): 0.22, Test Loss: 0.41, Test Correct Frac: 0.866
# Time: 0.47, Batch 31000, Train Loss (for batch): 0.35, Test Loss: 0.38, Test Correct Frac: 0.875
# Time: 0.49, Batch 31200, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.852
# Time: 0.48, Batch 31400, Train Loss (for batch): 0.15, Test Loss: 0.50, Test Correct Frac: 0.814
# Time: 0.48, Batch 31600, Train Loss (for batch): 0.02, Test Loss: 0.43, Test Correct Frac: 0.844
# Time: 0.48, Batch 31800, Train Loss (for batch): 0.00, Test Loss: 0.50, Test Correct Frac: 0.830
# Time: 0.49, Batch 32000, Train Loss (for batch): 0.02, Test Loss: 0.37, Test Correct Frac: 0.875
# Time: 0.48, Batch 32200, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.835
# Time: 0.48, Batch 32400, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.864
# Time: 0.49, Batch 32600, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.873
# Time: 0.48, Batch 32800, Train Loss (for batch): 0.00, Test Loss: 0.36, Test Correct Frac: 0.880
# Time: 0.48, Batch 33000, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.864
# Time: 0.49, Batch 33200, Train Loss (for batch): 0.32, Test Loss: 0.43, Test Correct Frac: 0.853
# Time: 0.48, Batch 33400, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.851
# Time: 0.49, Batch 33600, Train Loss (for batch): 1.08, Test Loss: 0.40, Test Correct Frac: 0.861
# Time: 0.48, Batch 33800, Train Loss (for batch): 0.01, Test Loss: 0.40, Test Correct Frac: 0.861
# Time: 0.48, Batch 34000, Train Loss (for batch): 0.02, Test Loss: 0.39, Test Correct Frac: 0.872
# Time: 0.48, Batch 34200, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.858
# Time: 0.50, Batch 34400, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.838
# Time: 0.49, Batch 34600, Train Loss (for batch): 0.00, Test Loss: 0.35, Test Correct Frac: 0.885
# Time: 0.48, Batch 34800, Train Loss (for batch): 0.29, Test Loss: 0.42, Test Correct Frac: 0.869
# Time: 0.48, Batch 35000, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.859
# Time: 0.49, Batch 35200, Train Loss (for batch): 0.01, Test Loss: 0.44, Test Correct Frac: 0.859
# Time: 0.48, Batch 35400, Train Loss (for batch): 0.00, Test Loss: 0.51, Test Correct Frac: 0.828
# Time: 0.48, Batch 35600, Train Loss (for batch): 0.57, Test Loss: 0.50, Test Correct Frac: 0.839
# Time: 0.48, Batch 35800, Train Loss (for batch): 0.01, Test Loss: 0.45, Test Correct Frac: 0.857
# Time: 0.47, Batch 36000, Train Loss (for batch): 0.04, Test Loss: 0.41, Test Correct Frac: 0.872
# Time: 0.49, Batch 36200, Train Loss (for batch): 0.31, Test Loss: 0.43, Test Correct Frac: 0.856
# Time: 0.48, Batch 36400, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.863
# Time: 0.48, Batch 36600, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.850
# Time: 0.49, Batch 36800, Train Loss (for batch): 0.01, Test Loss: 0.46, Test Correct Frac: 0.842
# Time: 0.49, Batch 37000, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.854
# Time: 0.48, Batch 37200, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.854
# Time: 0.48, Batch 37400, Train Loss (for batch): 0.42, Test Loss: 0.44, Test Correct Frac: 0.850
# Time: 0.48, Batch 37600, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.861
# Time: 0.48, Batch 37800, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.834
# Time: 0.49, Batch 38000, Train Loss (for batch): 0.00, Test Loss: 0.36, Test Correct Frac: 0.875
# Time: 0.48, Batch 38200, Train Loss (for batch): 0.02, Test Loss: 0.38, Test Correct Frac: 0.872
# Time: 0.48, Batch 38400, Train Loss (for batch): 0.06, Test Loss: 0.41, Test Correct Frac: 0.867
# Time: 0.48, Batch 38600, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.870
# Time: 0.49, Batch 38800, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.851
# Time: 0.48, Batch 39000, Train Loss (for batch): 1.43, Test Loss: 0.38, Test Correct Frac: 0.872
# Time: 0.48, Batch 39200, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.869
# Time: 0.48, Batch 39400, Train Loss (for batch): 0.01, Test Loss: 0.41, Test Correct Frac: 0.864
# Time: 0.49, Batch 39600, Train Loss (for batch): 0.02, Test Loss: 0.42, Test Correct Frac: 0.871
# Time: 0.48, Batch 39800, Train Loss (for batch): 0.00, Test Loss: 0.37, Test Correct Frac: 0.884
# Time: 0.48, Batch 40000, Train Loss (for batch): 1.06, Test Loss: 0.41, Test Correct Frac: 0.853
# Time: 0.48, Batch 40200, Train Loss (for batch): 0.17, Test Loss: 0.45, Test Correct Frac: 0.842
# Time: 0.48, Batch 40400, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.873
# Time: 0.48, Batch 40600, Train Loss (for batch): 0.01, Test Loss: 0.43, Test Correct Frac: 0.854
# Time: 0.48, Batch 40800, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.859
# Time: 0.49, Batch 41000, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.874
# Time: 0.49, Batch 41200, Train Loss (for batch): 0.01, Test Loss: 0.41, Test Correct Frac: 0.874
# Time: 0.48, Batch 41400, Train Loss (for batch): 0.53, Test Loss: 0.40, Test Correct Frac: 0.865
# Time: 0.49, Batch 41600, Train Loss (for batch): 0.27, Test Loss: 0.40, Test Correct Frac: 0.868
# Time: 0.49, Batch 41800, Train Loss (for batch): 0.03, Test Loss: 0.39, Test Correct Frac: 0.874
# Time: 0.48, Batch 42000, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.878
# Time: 0.48, Batch 42200, Train Loss (for batch): 0.06, Test Loss: 0.43, Test Correct Frac: 0.864
# Time: 0.48, Batch 42400, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.859
# Time: 0.49, Batch 42600, Train Loss (for batch): 0.01, Test Loss: 0.38, Test Correct Frac: 0.870
# ### EPOCH  1 ###
# Time: 0.42, Batch   0, Train Loss (for batch): 0.16, Test Loss: 0.38, Test Correct Frac: 0.874
# Time: 0.48, Batch 200, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.870
# Time: 0.48, Batch 400, Train Loss (for batch): 0.20, Test Loss: 0.44, Test Correct Frac: 0.862
# Time: 0.48, Batch 600, Train Loss (for batch): 0.00, Test Loss: 0.37, Test Correct Frac: 0.873
# Time: 0.48, Batch 800, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.874
# Time: 0.48, Batch 1000, Train Loss (for batch): 0.07, Test Loss: 0.48, Test Correct Frac: 0.844
# Time: 0.49, Batch 1200, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.873
# Time: 0.49, Batch 1400, Train Loss (for batch): 0.34, Test Loss: 0.41, Test Correct Frac: 0.864
# Time: 0.48, Batch 1600, Train Loss (for batch): 0.14, Test Loss: 0.44, Test Correct Frac: 0.848
# Time: 0.48, Batch 1800, Train Loss (for batch): 0.00, Test Loss: 0.35, Test Correct Frac: 0.879
# Time: 0.48, Batch 2000, Train Loss (for batch): 0.22, Test Loss: 0.44, Test Correct Frac: 0.845
# Time: 0.48, Batch 2200, Train Loss (for batch): 0.66, Test Loss: 0.42, Test Correct Frac: 0.844
# Time: 0.48, Batch 2400, Train Loss (for batch): 0.01, Test Loss: 0.34, Test Correct Frac: 0.888
# Time: 0.49, Batch 2600, Train Loss (for batch): 0.04, Test Loss: 0.36, Test Correct Frac: 0.878
# Time: 0.48, Batch 2800, Train Loss (for batch): 0.02, Test Loss: 0.42, Test Correct Frac: 0.856
# Time: 0.48, Batch 3000, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.873
# Time: 0.48, Batch 3200, Train Loss (for batch): 0.02, Test Loss: 0.46, Test Correct Frac: 0.844
# Time: 0.48, Batch 3400, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.866
# Time: 0.48, Batch 3600, Train Loss (for batch): 0.01, Test Loss: 0.41, Test Correct Frac: 0.861
# Time: 0.48, Batch 3800, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.868
# Time: 0.49, Batch 4000, Train Loss (for batch): 0.12, Test Loss: 0.48, Test Correct Frac: 0.840
# Time: 0.48, Batch 4200, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.860
# Time: 0.48, Batch 4400, Train Loss (for batch): 0.21, Test Loss: 0.43, Test Correct Frac: 0.851
# Time: 0.48, Batch 4600, Train Loss (for batch): 0.09, Test Loss: 0.46, Test Correct Frac: 0.833
# Time: 0.48, Batch 4800, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.858
# Time: 0.48, Batch 5000, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.868
# Time: 0.48, Batch 5200, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.838
# Time: 0.48, Batch 5400, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.873
# Time: 0.48, Batch 5600, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.865
# Time: 0.49, Batch 5800, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.875
# Time: 0.48, Batch 6000, Train Loss (for batch): 0.00, Test Loss: 0.34, Test Correct Frac: 0.884
# Time: 0.48, Batch 6200, Train Loss (for batch): 0.03, Test Loss: 0.40, Test Correct Frac: 0.861
# Time: 0.48, Batch 6400, Train Loss (for batch): 0.01, Test Loss: 0.36, Test Correct Frac: 0.885
# Time: 0.48, Batch 6600, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.854
# Time: 0.48, Batch 6800, Train Loss (for batch): 0.09, Test Loss: 0.41, Test Correct Frac: 0.861
# Time: 0.48, Batch 7000, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.854
# Time: 0.49, Batch 7200, Train Loss (for batch): 0.08, Test Loss: 0.40, Test Correct Frac: 0.871
# Time: 0.47, Batch 7400, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.853
# Time: 0.48, Batch 7600, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.849
# Time: 0.49, Batch 7800, Train Loss (for batch): 0.00, Test Loss: 0.37, Test Correct Frac: 0.871
# Time: 0.48, Batch 8000, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.869
# Time: 0.49, Batch 8200, Train Loss (for batch): 0.04, Test Loss: 0.44, Test Correct Frac: 0.864
# Time: 0.47, Batch 8400, Train Loss (for batch): 0.06, Test Loss: 0.37, Test Correct Frac: 0.871
# Time: 0.48, Batch 8600, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.873
# Time: 0.48, Batch 8800, Train Loss (for batch): 0.17, Test Loss: 0.46, Test Correct Frac: 0.853
# Time: 0.47, Batch 9000, Train Loss (for batch): 0.97, Test Loss: 0.39, Test Correct Frac: 0.876
# Time: 0.48, Batch 9200, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.843
# Time: 0.48, Batch 9400, Train Loss (for batch): 0.58, Test Loss: 0.44, Test Correct Frac: 0.848
# Time: 0.47, Batch 9600, Train Loss (for batch): 0.03, Test Loss: 0.40, Test Correct Frac: 0.858
# Time: 0.47, Batch 9800, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.866
# Time: 0.48, Batch 10000, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.848
# Time: 0.49, Batch 10200, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.849
# Time: 0.49, Batch 10400, Train Loss (for batch): 0.08, Test Loss: 0.44, Test Correct Frac: 0.843
# Time: 0.48, Batch 10600, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.861
# Time: 0.49, Batch 10800, Train Loss (for batch): 0.09, Test Loss: 0.46, Test Correct Frac: 0.848
# Time: 0.48, Batch 11000, Train Loss (for batch): 0.04, Test Loss: 0.48, Test Correct Frac: 0.852
# Time: 0.49, Batch 11200, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.851
# Time: 0.48, Batch 11400, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.863
# Time: 0.49, Batch 11600, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.871
# Time: 0.48, Batch 11800, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.864
# Time: 0.48, Batch 12000, Train Loss (for batch): 0.08, Test Loss: 0.43, Test Correct Frac: 0.853
# Time: 0.48, Batch 12200, Train Loss (for batch): 0.30, Test Loss: 0.45, Test Correct Frac: 0.852
# Time: 0.49, Batch 12400, Train Loss (for batch): 0.01, Test Loss: 0.42, Test Correct Frac: 0.868
# Time: 0.49, Batch 12600, Train Loss (for batch): 0.06, Test Loss: 0.41, Test Correct Frac: 0.864
# Time: 0.47, Batch 12800, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.858
# Time: 0.48, Batch 13000, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.868
# Time: 0.48, Batch 13200, Train Loss (for batch): 0.31, Test Loss: 0.41, Test Correct Frac: 0.863
# Time: 0.48, Batch 13400, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.833
# Time: 0.48, Batch 13600, Train Loss (for batch): 0.05, Test Loss: 0.49, Test Correct Frac: 0.833
# Time: 0.48, Batch 13800, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.860
# Time: 0.48, Batch 14000, Train Loss (for batch): 0.06, Test Loss: 0.41, Test Correct Frac: 0.861
# Time: 0.48, Batch 14200, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.866
# Time: 0.48, Batch 14400, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.867
# Time: 0.48, Batch 14600, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.869
# Time: 0.48, Batch 14800, Train Loss (for batch): 0.01, Test Loss: 0.37, Test Correct Frac: 0.873
# Time: 0.48, Batch 15000, Train Loss (for batch): 0.01, Test Loss: 0.41, Test Correct Frac: 0.865
# Time: 0.47, Batch 15200, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.858
# Time: 0.48, Batch 15400, Train Loss (for batch): 0.39, Test Loss: 0.39, Test Correct Frac: 0.868
# Time: 0.49, Batch 15600, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.857
# Time: 0.47, Batch 15800, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.858
# Time: 0.48, Batch 16000, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.859
# Time: 0.48, Batch 16200, Train Loss (for batch): 1.12, Test Loss: 0.44, Test Correct Frac: 0.848
# Time: 0.49, Batch 16400, Train Loss (for batch): 0.04, Test Loss: 0.38, Test Correct Frac: 0.884
# Time: 0.49, Batch 16600, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.841
# Time: 0.48, Batch 16800, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.859
# Time: 0.48, Batch 17000, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.864
# Time: 0.47, Batch 17200, Train Loss (for batch): 0.00, Test Loss: 0.36, Test Correct Frac: 0.877
# Time: 0.48, Batch 17400, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.870
# Time: 0.48, Batch 17600, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.871
# Time: 0.48, Batch 17800, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.860
# Time: 0.48, Batch 18000, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.866
# Time: 0.47, Batch 18200, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.857
# Time: 0.48, Batch 18400, Train Loss (for batch): 0.38, Test Loss: 0.43, Test Correct Frac: 0.851
# Time: 0.49, Batch 18600, Train Loss (for batch): 0.09, Test Loss: 0.43, Test Correct Frac: 0.864
# Time: 0.48, Batch 18800, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.867
# Time: 0.48, Batch 19000, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.858
# Time: 0.48, Batch 19200, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.864
# Time: 0.47, Batch 19400, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.867
# Time: 0.47, Batch 19600, Train Loss (for batch): 0.04, Test Loss: 0.41, Test Correct Frac: 0.869
# Time: 0.48, Batch 19800, Train Loss (for batch): 0.68, Test Loss: 0.47, Test Correct Frac: 0.845
# Time: 0.48, Batch 20000, Train Loss (for batch): 1.80, Test Loss: 0.42, Test Correct Frac: 0.864
# Time: 0.48, Batch 20200, Train Loss (for batch): 0.00, Test Loss: 0.51, Test Correct Frac: 0.845
# Time: 0.48, Batch 20400, Train Loss (for batch): 0.01, Test Loss: 0.43, Test Correct Frac: 0.860
# Time: 0.48, Batch 20600, Train Loss (for batch): 0.03, Test Loss: 0.43, Test Correct Frac: 0.854
# Time: 0.48, Batch 20800, Train Loss (for batch): 0.00, Test Loss: 0.48, Test Correct Frac: 0.851
# Time: 0.48, Batch 21000, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.862
# Time: 0.48, Batch 21200, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.866
# Time: 0.48, Batch 21400, Train Loss (for batch): 0.03, Test Loss: 0.46, Test Correct Frac: 0.843
# Time: 0.48, Batch 21600, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.861
# Time: 0.48, Batch 21800, Train Loss (for batch): 0.01, Test Loss: 0.40, Test Correct Frac: 0.872
# Time: 0.47, Batch 22000, Train Loss (for batch): 0.04, Test Loss: 0.41, Test Correct Frac: 0.862
# Time: 0.48, Batch 22200, Train Loss (for batch): 0.25, Test Loss: 0.45, Test Correct Frac: 0.845
# Time: 0.48, Batch 22400, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.874
# Time: 0.48, Batch 22600, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.851
# Time: 0.49, Batch 22800, Train Loss (for batch): 0.08, Test Loss: 0.37, Test Correct Frac: 0.864
# Time: 0.48, Batch 23000, Train Loss (for batch): 0.21, Test Loss: 0.42, Test Correct Frac: 0.857
# Time: 0.48, Batch 23200, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.866
# Time: 0.48, Batch 23400, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.875
# Time: 0.48, Batch 23600, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.872
# Time: 0.48, Batch 23800, Train Loss (for batch): 0.01, Test Loss: 0.46, Test Correct Frac: 0.857
# Time: 0.49, Batch 24000, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.874
# Time: 0.48, Batch 24200, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.862
# Time: 0.48, Batch 24400, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.865
# Time: 0.47, Batch 24600, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.854
# Time: 0.48, Batch 24800, Train Loss (for batch): 0.27, Test Loss: 0.50, Test Correct Frac: 0.834
# Time: 0.48, Batch 25000, Train Loss (for batch): 0.16, Test Loss: 0.52, Test Correct Frac: 0.846
# Time: 0.49, Batch 25200, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.877
# Time: 0.49, Batch 25400, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.860
# Time: 0.48, Batch 25600, Train Loss (for batch): 0.38, Test Loss: 0.41, Test Correct Frac: 0.870
# Time: 0.47, Batch 25800, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.873
# Time: 0.49, Batch 26000, Train Loss (for batch): 0.01, Test Loss: 0.39, Test Correct Frac: 0.879
# Time: 0.50, Batch 26200, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.872
# Time: 0.48, Batch 26400, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.854
# Time: 0.48, Batch 26600, Train Loss (for batch): 0.02, Test Loss: 0.42, Test Correct Frac: 0.861
# Time: 0.48, Batch 26800, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.873
# Time: 0.48, Batch 27000, Train Loss (for batch): 0.01, Test Loss: 0.44, Test Correct Frac: 0.859
# Time: 0.48, Batch 27200, Train Loss (for batch): 0.03, Test Loss: 0.44, Test Correct Frac: 0.861
# Time: 0.47, Batch 27400, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.878
# Time: 0.48, Batch 27600, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.862
# Time: 0.48, Batch 27800, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.855
# Time: 0.48, Batch 28000, Train Loss (for batch): 0.01, Test Loss: 0.45, Test Correct Frac: 0.862
# Time: 0.48, Batch 28200, Train Loss (for batch): 0.07, Test Loss: 0.44, Test Correct Frac: 0.865
# Time: 0.48, Batch 28400, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.865
# Time: 0.48, Batch 28600, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.882
# Time: 0.48, Batch 28800, Train Loss (for batch): 0.01, Test Loss: 0.46, Test Correct Frac: 0.846
# Time: 0.47, Batch 29000, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.872
# Time: 0.48, Batch 29200, Train Loss (for batch): 0.00, Test Loss: 0.50, Test Correct Frac: 0.836
# Time: 0.48, Batch 29400, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.863
# Time: 0.48, Batch 29600, Train Loss (for batch): 0.06, Test Loss: 0.44, Test Correct Frac: 0.855
# Time: 0.47, Batch 29800, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.861
# Time: 0.48, Batch 30000, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.858
# Time: 0.47, Batch 30200, Train Loss (for batch): 0.56, Test Loss: 0.42, Test Correct Frac: 0.864
# Time: 0.48, Batch 30400, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.865
# Time: 0.47, Batch 30600, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.885
# Time: 0.48, Batch 30800, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.860
# Time: 0.48, Batch 31000, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.861
# Time: 0.48, Batch 31200, Train Loss (for batch): 0.04, Test Loss: 0.40, Test Correct Frac: 0.866
# Time: 0.48, Batch 31400, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.873
# Time: 0.48, Batch 31600, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.857
# Time: 0.48, Batch 31800, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.849
# Time: 0.48, Batch 32000, Train Loss (for batch): 0.04, Test Loss: 0.43, Test Correct Frac: 0.864
# Time: 0.48, Batch 32200, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.861
# Time: 0.48, Batch 32400, Train Loss (for batch): 0.02, Test Loss: 0.46, Test Correct Frac: 0.862
# Time: 0.49, Batch 32600, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.856
# Time: 0.48, Batch 32800, Train Loss (for batch): 0.01, Test Loss: 0.46, Test Correct Frac: 0.853
# Time: 0.48, Batch 33000, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.855
# Time: 0.48, Batch 33200, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.872
# Time: 0.48, Batch 33400, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.853
# Time: 0.47, Batch 33600, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.862
# Time: 0.48, Batch 33800, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.859
# Time: 0.48, Batch 34000, Train Loss (for batch): 0.36, Test Loss: 0.44, Test Correct Frac: 0.863
# Time: 0.48, Batch 34200, Train Loss (for batch): 0.01, Test Loss: 0.49, Test Correct Frac: 0.840
# Time: 0.48, Batch 34400, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.867
# Time: 0.48, Batch 34600, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.864
# Time: 0.48, Batch 34800, Train Loss (for batch): 0.02, Test Loss: 0.44, Test Correct Frac: 0.854
# Time: 0.47, Batch 35000, Train Loss (for batch): 0.25, Test Loss: 0.41, Test Correct Frac: 0.871
# Time: 0.48, Batch 35200, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.880
# Time: 0.49, Batch 35400, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.865
# Time: 0.48, Batch 35600, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.865
# Time: 0.47, Batch 35800, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.876
# Time: 0.48, Batch 36000, Train Loss (for batch): 0.00, Test Loss: 0.50, Test Correct Frac: 0.843
# Time: 0.48, Batch 36200, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.873
# Time: 0.47, Batch 36400, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.871
# Time: 0.49, Batch 36600, Train Loss (for batch): 0.03, Test Loss: 0.40, Test Correct Frac: 0.865
# Time: 0.48, Batch 36800, Train Loss (for batch): 0.01, Test Loss: 0.43, Test Correct Frac: 0.862
# Time: 0.48, Batch 37000, Train Loss (for batch): 0.01, Test Loss: 0.38, Test Correct Frac: 0.879
# Time: 0.48, Batch 37200, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.866
# Time: 0.48, Batch 37400, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.860
# Time: 0.48, Batch 37600, Train Loss (for batch): 0.01, Test Loss: 0.44, Test Correct Frac: 0.873
# Time: 0.48, Batch 37800, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.866
# Time: 0.48, Batch 38000, Train Loss (for batch): 0.02, Test Loss: 0.44, Test Correct Frac: 0.861
# Time: 0.48, Batch 38200, Train Loss (for batch): 0.85, Test Loss: 0.40, Test Correct Frac: 0.880
# Time: 0.48, Batch 38400, Train Loss (for batch): 0.12, Test Loss: 0.46, Test Correct Frac: 0.857
# Time: 0.49, Batch 38600, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.856
# Time: 0.48, Batch 38800, Train Loss (for batch): 0.03, Test Loss: 0.50, Test Correct Frac: 0.853
# Time: 0.47, Batch 39000, Train Loss (for batch): 0.02, Test Loss: 0.55, Test Correct Frac: 0.834
# Time: 0.48, Batch 39200, Train Loss (for batch): 0.01, Test Loss: 0.49, Test Correct Frac: 0.851
# Time: 0.47, Batch 39400, Train Loss (for batch): 0.01, Test Loss: 0.48, Test Correct Frac: 0.858
# Time: 0.47, Batch 39600, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.847
# Time: 0.47, Batch 39800, Train Loss (for batch): 0.00, Test Loss: 0.48, Test Correct Frac: 0.852
# Time: 0.48, Batch 40000, Train Loss (for batch): 0.11, Test Loss: 0.40, Test Correct Frac: 0.876
# Time: 0.47, Batch 40200, Train Loss (for batch): 0.00, Test Loss: 0.52, Test Correct Frac: 0.830
# Time: 0.47, Batch 40400, Train Loss (for batch): 0.12, Test Loss: 0.45, Test Correct Frac: 0.858
# Time: 0.48, Batch 40600, Train Loss (for batch): 0.27, Test Loss: 0.42, Test Correct Frac: 0.873
# Time: 0.48, Batch 40800, Train Loss (for batch): 0.03, Test Loss: 0.40, Test Correct Frac: 0.870
# Time: 0.47, Batch 41000, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.873
# Time: 0.47, Batch 41200, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.861
# Time: 0.48, Batch 41400, Train Loss (for batch): 0.04, Test Loss: 0.44, Test Correct Frac: 0.850
# Time: 0.48, Batch 41600, Train Loss (for batch): 0.09, Test Loss: 0.39, Test Correct Frac: 0.881
# Time: 0.48, Batch 41800, Train Loss (for batch): 0.38, Test Loss: 0.43, Test Correct Frac: 0.859
# Time: 0.48, Batch 42000, Train Loss (for batch): 0.00, Test Loss: 0.38, Test Correct Frac: 0.870
# Time: 0.47, Batch 42200, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.859
# Time: 0.47, Batch 42400, Train Loss (for batch): 0.40, Test Loss: 0.43, Test Correct Frac: 0.858
# Time: 0.49, Batch 42600, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.868
# ### EPOCH  2 ###
# Time: 0.41, Batch   0, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.868
# Time: 0.48, Batch 200, Train Loss (for batch): 0.00, Test Loss: 0.40, Test Correct Frac: 0.869
# Time: 0.48, Batch 400, Train Loss (for batch): 0.52, Test Loss: 0.46, Test Correct Frac: 0.851
# Time: 0.48, Batch 600, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.875
# Time: 0.48, Batch 800, Train Loss (for batch): 0.03, Test Loss: 0.39, Test Correct Frac: 0.871
# Time: 0.48, Batch 1000, Train Loss (for batch): 0.03, Test Loss: 0.44, Test Correct Frac: 0.862
# Time: 0.48, Batch 1200, Train Loss (for batch): 0.00, Test Loss: 0.51, Test Correct Frac: 0.844
# Time: 0.47, Batch 1400, Train Loss (for batch): 0.07, Test Loss: 0.50, Test Correct Frac: 0.847
# Time: 0.48, Batch 1600, Train Loss (for batch): 0.02, Test Loss: 0.43, Test Correct Frac: 0.875
# Time: 0.47, Batch 1800, Train Loss (for batch): 0.02, Test Loss: 0.43, Test Correct Frac: 0.864
# Time: 0.48, Batch 2000, Train Loss (for batch): 0.34, Test Loss: 0.54, Test Correct Frac: 0.840
# Time: 0.48, Batch 2200, Train Loss (for batch): 0.00, Test Loss: 0.50, Test Correct Frac: 0.843
# Time: 0.48, Batch 2400, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.874
# Time: 0.48, Batch 2600, Train Loss (for batch): 0.00, Test Loss: 0.39, Test Correct Frac: 0.888
# Time: 0.48, Batch 2800, Train Loss (for batch): 0.02, Test Loss: 0.42, Test Correct Frac: 0.869
# Time: 0.48, Batch 3000, Train Loss (for batch): 0.18, Test Loss: 0.47, Test Correct Frac: 0.854
# Time: 0.48, Batch 3200, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.861
# Time: 0.48, Batch 3400, Train Loss (for batch): 0.71, Test Loss: 0.45, Test Correct Frac: 0.856
# Time: 0.48, Batch 3600, Train Loss (for batch): 0.00, Test Loss: 0.42, Test Correct Frac: 0.868
# Time: 0.48, Batch 3800, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.853
# Time: 0.48, Batch 4000, Train Loss (for batch): 0.75, Test Loss: 0.48, Test Correct Frac: 0.860
# Time: 0.48, Batch 4200, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.847
# Time: 0.47, Batch 4400, Train Loss (for batch): 0.01, Test Loss: 0.45, Test Correct Frac: 0.858
# Time: 0.47, Batch 4600, Train Loss (for batch): 0.22, Test Loss: 0.42, Test Correct Frac: 0.873
# Time: 0.48, Batch 4800, Train Loss (for batch): 0.32, Test Loss: 0.43, Test Correct Frac: 0.869
# Time: 0.48, Batch 5000, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.860
# Time: 0.48, Batch 5200, Train Loss (for batch): 0.04, Test Loss: 0.43, Test Correct Frac: 0.865
# Time: 0.48, Batch 5400, Train Loss (for batch): 0.05, Test Loss: 0.41, Test Correct Frac: 0.867
# Time: 0.48, Batch 5600, Train Loss (for batch): 0.06, Test Loss: 0.48, Test Correct Frac: 0.837
# Time: 0.49, Batch 5800, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.848
# Time: 0.49, Batch 6000, Train Loss (for batch): 1.26, Test Loss: 0.44, Test Correct Frac: 0.861
# Time: 0.49, Batch 6200, Train Loss (for batch): 0.65, Test Loss: 0.43, Test Correct Frac: 0.874
# Time: 0.48, Batch 6400, Train Loss (for batch): 0.00, Test Loss: 0.51, Test Correct Frac: 0.847
# Time: 0.48, Batch 6600, Train Loss (for batch): 0.38, Test Loss: 0.46, Test Correct Frac: 0.866
# Time: 0.48, Batch 6800, Train Loss (for batch): 0.26, Test Loss: 0.45, Test Correct Frac: 0.855
# Time: 0.49, Batch 7000, Train Loss (for batch): 0.02, Test Loss: 0.45, Test Correct Frac: 0.856
# Time: 0.48, Batch 7200, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.855
# Time: 0.48, Batch 7400, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.871
# Time: 0.48, Batch 7600, Train Loss (for batch): 0.00, Test Loss: 0.41, Test Correct Frac: 0.866
# Time: 0.48, Batch 7800, Train Loss (for batch): 0.00, Test Loss: 0.51, Test Correct Frac: 0.842
# Time: 0.48, Batch 8000, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.865
# Time: 0.48, Batch 8200, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.863
# Time: 0.49, Batch 8400, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.860
# Time: 0.49, Batch 8600, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.862
# Time: 0.47, Batch 8800, Train Loss (for batch): 0.03, Test Loss: 0.42, Test Correct Frac: 0.869
# Time: 0.48, Batch 9000, Train Loss (for batch): 0.04, Test Loss: 0.41, Test Correct Frac: 0.877
# Time: 0.48, Batch 9200, Train Loss (for batch): 0.00, Test Loss: 0.47, Test Correct Frac: 0.856
# Time: 0.48, Batch 9400, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.868
# Time: 0.49, Batch 9600, Train Loss (for batch): 0.02, Test Loss: 0.42, Test Correct Frac: 0.867
# Time: 0.48, Batch 9800, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.863
# Time: 0.48, Batch 10000, Train Loss (for batch): 0.08, Test Loss: 0.47, Test Correct Frac: 0.861
# Time: 0.48, Batch 10200, Train Loss (for batch): 0.50, Test Loss: 0.48, Test Correct Frac: 0.858
# Time: 0.49, Batch 10400, Train Loss (for batch): 0.03, Test Loss: 0.48, Test Correct Frac: 0.864
# Time: 0.47, Batch 10600, Train Loss (for batch): 0.00, Test Loss: 0.58, Test Correct Frac: 0.831
# Time: 0.48, Batch 10800, Train Loss (for batch): 0.03, Test Loss: 0.49, Test Correct Frac: 0.856
# Time: 0.48, Batch 11000, Train Loss (for batch): 0.00, Test Loss: 0.56, Test Correct Frac: 0.835
# Time: 0.48, Batch 11200, Train Loss (for batch): 0.06, Test Loss: 0.46, Test Correct Frac: 0.863
# Time: 0.48, Batch 11400, Train Loss (for batch): 0.00, Test Loss: 0.43, Test Correct Frac: 0.882
# Time: 0.49, Batch 11600, Train Loss (for batch): 0.01, Test Loss: 0.49, Test Correct Frac: 0.858
# Time: 0.48, Batch 11800, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.855
# Time: 0.48, Batch 12000, Train Loss (for batch): 0.00, Test Loss: 0.50, Test Correct Frac: 0.843
# Time: 0.48, Batch 12200, Train Loss (for batch): 0.00, Test Loss: 0.46, Test Correct Frac: 0.867
# Time: 0.48, Batch 12400, Train Loss (for batch): 0.00, Test Loss: 0.45, Test Correct Frac: 0.867
# Time: 0.48, Batch 12600, Train Loss (for batch): 0.01, Test Loss: 0.41, Test Correct Frac: 0.879
# Time: 0.48, Batch 12800, Train Loss (for batch): 0.00, Test Loss: 0.44, Test Correct Frac: 0.863
# Time: 0.48, Batch 13000, Train Loss (for batch): 0.00, Test Loss: 0.49, Test Correct Frac: 0.855
# Time: 0.48, Batch 13200, Train Loss (for batch): 0.01, Test Loss: 0.47, Test Correct Frac: 0.869
# ...
# Time: 4.65, Batch 1800, Train Loss (for batch): 0.10, Test Loss: 0.57, Test Correct Frac: 0.820
# Time: 4.11, Batch 2000, Train Loss (for batch): 0.18, Test Loss: 0.49, Test Correct Frac: 0.829
# Time: 4.32, Batch 2200, Train Loss (for batch): 0.38, Test Loss: 0.66, Test Correct Frac: 0.761
# Time: 4.10, Batch 2400, Train Loss (for batch): 0.09, Test Loss: 0.53, Test Correct Frac: 0.806
# Time: 4.16, Batch 2600, Train Loss (for batch): 0.20, Test Loss: 0.63, Test Correct Frac: 0.759
# ### EPOCH  1 ###
# Time: 2.38, Batch   0, Train Loss (for batch): 0.14, Test Loss: 0.51, Test Correct Frac: 0.802
# Time: 4.04, Batch 200, Train Loss (for batch): 0.27, Test Loss: 0.56, Test Correct Frac: 0.791
# Time: 4.03, Batch 400, Train Loss (for batch): 0.21, Test Loss: 0.68, Test Correct Frac: 0.784
# Time: 4.06, Batch 600, Train Loss (for batch): 0.25, Test Loss: 0.63, Test Correct Frac: 0.773
# Time: 4.00, Batch 800, Train Loss (for batch): 0.28, Test Loss: 0.63, Test Correct Frac: 0.798
# Time: 4.12, Batch 1000, Train Loss (for batch): 0.04, Test Loss: 0.50, Test Correct Frac: 0.836
# Time: 4.07, Batch 1200, Train Loss (for batch): 0.22, Test Loss: 0.51, Test Correct Frac: 0.849
# Time: 4.04, Batch 1400, Train Loss (for batch): 0.14, Test Loss: 0.48, Test Correct Frac: 0.842
# Time: 4.02, Batch 1600, Train Loss (for batch): 0.07, Test Loss: 0.46, Test Correct Frac: 0.847
# Time: 4.03, Batch 1800, Train Loss (for batch): 0.19, Test Loss: 0.58, Test Correct Frac: 0.808
# Time: 4.13, Batch 2000, Train Loss (for batch): 0.08, Test Loss: 0.51, Test Correct Frac: 0.830
# Time: 4.13, Batch 2200, Train Loss (for batch): 0.58, Test Loss: 0.81, Test Correct Frac: 0.759
# Time: 4.06, Batch 2400, Train Loss (for batch): 1.24, Test Loss: 3.96, Test Correct Frac: 0.683
# Time: 4.05, Batch 2600, Train Loss (for batch): 0.26, Test Loss: 11.92, Test Correct Frac: 0.777
# ### EPOCH  2 ###
# Time: 2.36, Batch   0, Train Loss (for batch): 0.38, Test Loss: 1.90, Test Correct Frac: 0.845
# Time: 4.05, Batch 200, Train Loss (for batch): 0.40, Test Loss: 12.59, Test Correct Frac: 0.786
# Time: 4.07, Batch 400, Train Loss (for batch): 66.76, Test Loss: 0.89, Test Correct Frac: 0.707
# Time: 4.17, Batch 600, Train Loss (for batch): 0.41, Test Loss: 22.89, Test Correct Frac: 0.456
# Time: 4.18, Batch 800, Train Loss (for batch): 0.10, Test Loss: 0.65, Test Correct Frac: 0.795
# Time: 4.06, Batch 1000, Train Loss (for batch): 0.27, Test Loss: 0.58, Test Correct Frac: 0.820
# Time: 4.12, Batch 1200, Train Loss (for batch): 0.56, Test Loss: 1.19, Test Correct Frac: 0.659
# Time: 4.04, Batch 1400, Train Loss (for batch): 0.30, Test Loss: 2.39, Test Correct Frac: 0.804
# Time: 4.06, Batch 1600, Train Loss (for batch): 0.28, Test Loss: 18.00, Test Correct Frac: 0.726
# Time: 4.04, Batch 1800, Train Loss (for batch): 0.35, Test Loss: 111.91, Test Correct Frac: 0.735
# Time: 4.07, Batch 2000, Train Loss (for batch): 0.23, Test Loss: 85.04, Test Correct Frac: 0.726
# Time: 4.06, Batch 2200, Train Loss (for batch): 0.23, Test Loss: 124.97, Test Correct Frac: 0.738
# Time: 4.08, Batch 2400, Train Loss (for batch): 0.40, Test Loss: 0.69, Test Correct Frac: 0.712
# Time: 4.28, Batch 2600, Train Loss (for batch): 0.31, Test Loss: 0.67, Test Correct Frac: 0.712
#
#
#  Net with  5 layers, 500 wide. Using learning rate of 0.001000 and 64 batches
#
#
#  Net with  8 layers, 100 wide. Using learning rate of 0.001000 and 64 batches
# ### EPOCH  0 ###
# Time: 0.12, Batch   0, Train Loss (for batch): 6.35, Test Loss: 1.29, Test Correct Frac: 0.634
# Time: 1.06, Batch 200, Train Loss (for batch): 0.37, Test Loss: 0.83, Test Correct Frac: 0.717
# Time: 1.07, Batch 400, Train Loss (for batch): 0.18, Test Loss: 0.59, Test Correct Frac: 0.781
# Time: 0.98, Batch 600, Train Loss (for batch): 0.70, Test Loss: 0.55, Test Correct Frac: 0.765
# Time: 1.12, Batch 800, Train Loss (for batch): 0.13, Test Loss: 0.57, Test Correct Frac: 0.785
# Time: 1.16, Batch 1000, Train Loss (for batch): 0.25, Test Loss: 0.50, Test Correct Frac: 0.813
# Time: 1.19, Batch 1200, Train Loss (for batch): 0.21, Test Loss: 0.44, Test Correct Frac: 0.848
# Time: 1.21, Batch 1400, Train Loss (for batch): 0.09, Test Loss: 0.45, Test Correct Frac: 0.854
# Time: 1.16, Batch 1600, Train Loss (for batch): 0.30, Test Loss: 0.44, Test Correct Frac: 0.853
# Time: 1.13, Batch 1800, Train Loss (for batch): 0.19, Test Loss: 0.55, Test Correct Frac: 0.824
# Time: 1.10, Batch 2000, Train Loss (for batch): 0.15, Test Loss: 0.53, Test Correct Frac: 0.847
# Time: 1.12, Batch 2200, Train Loss (for batch): 0.36, Test Loss: 0.52, Test Correct Frac: 0.823
# Time: 1.07, Batch 2400, Train Loss (for batch): 0.05, Test Loss: 0.50, Test Correct Frac: 0.846
# Time: 1.14, Batch 2600, Train Loss (for batch): 0.14, Test Loss: 0.48, Test Correct Frac: 0.830
# ### EPOCH  1 ###
# Time: 0.54, Batch   0, Train Loss (for batch): 0.13, Test Loss: 0.43, Test Correct Frac: 0.857
# Time: 1.19, Batch 200, Train Loss (for batch): 0.19, Test Loss: 0.42, Test Correct Frac: 0.872
# Time: 1.21, Batch 400, Train Loss (for batch): 0.16, Test Loss: 0.60, Test Correct Frac: 0.840
# Time: 1.13, Batch 600, Train Loss (for batch): 0.16, Test Loss: 0.42, Test Correct Frac: 0.866
# Time: 1.14, Batch 800, Train Loss (for batch): 0.26, Test Loss: 0.40, Test Correct Frac: 0.867
# Time: 1.16, Batch 1000, Train Loss (for batch): 0.05, Test Loss: 0.38, Test Correct Frac: 0.876
# Time: 1.17, Batch 1200, Train Loss (for batch): 0.57, Test Loss: 0.89, Test Correct Frac: 0.822
# Time: 1.16, Batch 1400, Train Loss (for batch): 0.12, Test Loss: 0.38, Test Correct Frac: 0.875
# Time: 1.15, Batch 1600, Train Loss (for batch): 0.08, Test Loss: 0.45, Test Correct Frac: 0.844
# Time: 1.19, Batch 1800, Train Loss (for batch): 0.14, Test Loss: 0.37, Test Correct Frac: 0.877
# Time: 1.21, Batch 2000, Train Loss (for batch): 0.05, Test Loss: 0.41, Test Correct Frac: 0.860
# Time: 1.20, Batch 2200, Train Loss (for batch): 0.15, Test Loss: 0.38, Test Correct Frac: 0.881
# Time: 1.16, Batch 2400, Train Loss (for batch): 0.09, Test Loss: 0.43, Test Correct Frac: 0.871
# Time: 1.18, Batch 2600, Train Loss (for batch): 0.10, Test Loss: 0.36, Test Correct Frac: 0.881
# ### EPOCH  2 ###
# Time: 0.52, Batch   0, Train Loss (for batch): 0.07, Test Loss: 0.45, Test Correct Frac: 0.853
# Time: 1.19, Batch 200, Train Loss (for batch): 0.10, Test Loss: 0.33, Test Correct Frac: 0.889
# Time: 1.17, Batch 400, Train Loss (for batch): 0.22, Test Loss: 0.43, Test Correct Frac: 0.861
# Time: 1.22, Batch 600, Train Loss (for batch): 0.08, Test Loss: 0.37, Test Correct Frac: 0.877
# Time: 1.15, Batch 800, Train Loss (for batch): 0.07, Test Loss: 0.34, Test Correct Frac: 0.875
# Time: 1.18, Batch 1000, Train Loss (for batch): 0.10, Test Loss: 0.31, Test Correct Frac: 0.893
# Time: 1.14, Batch 1200, Train Loss (for batch): 0.17, Test Loss: 0.42, Test Correct Frac: 0.858
# Time: 1.16, Batch 1400, Train Loss (for batch): 0.05, Test Loss: 0.40, Test Correct Frac: 0.875
# Time: 1.18, Batch 1600, Train Loss (for batch): 0.11, Test Loss: 0.37, Test Correct Frac: 0.857
# Time: 1.20, Batch 1800, Train Loss (for batch): 0.13, Test Loss: 0.36, Test Correct Frac: 0.889
# Time: 1.15, Batch 2000, Train Loss (for batch): 0.04, Test Loss: 0.36, Test Correct Frac: 0.886
# Time: 1.31, Batch 2200, Train Loss (for batch): 0.08, Test Loss: 0.42, Test Correct Frac: 0.859
# Time: 1.21, Batch 2400, Train Loss (for batch): 0.23, Test Loss: 0.38, Test Correct Frac: 0.861
# Time: 1.19, Batch 2600, Train Loss (for batch): 0.14, Test Loss: 0.38, Test Correct Frac: 0.872
#
#
#  Net with  8 layers, 100 wide. Using learning rate of 0.001000 and 64 batches
#
#
#  Net with  8 layers, 300 wide. Using learning rate of 0.001000 and 64 batches
# ### EPOCH  0 ###
# Time: 1.17, Batch   0, Train Loss (for batch): 3.88, Test Loss: 0.93, Test Correct Frac: 0.588
# Time: 3.34, Batch 200, Train Loss (for batch): 0.48, Test Loss: 0.73, Test Correct Frac: 0.687
# Time: 3.28, Batch 400, Train Loss (for batch): 0.24, Test Loss: 1.43, Test Correct Frac: 0.707
# Time: 3.10, Batch 600, Train Loss (for batch): 0.49, Test Loss: 0.63, Test Correct Frac: 0.731
# Time: 3.55, Batch 800, Train Loss (for batch): 0.20, Test Loss: 0.64, Test Correct Frac: 0.705
# Time: 3.79, Batch 1000, Train Loss (for batch): 0.40, Test Loss: 0.54, Test Correct Frac: 0.790
# Time: 3.84, Batch 1200, Train Loss (for batch): 0.20, Test Loss: 0.60, Test Correct Frac: 0.744
# Time: 3.76, Batch 1400, Train Loss (for batch): 0.13, Test Loss: 0.54, Test Correct Frac: 0.815
# Time: 3.75, Batch 1600, Train Loss (for batch): 0.49, Test Loss: 0.61, Test Correct Frac: 0.787
# Time: 3.64, Batch 1800, Train Loss (for batch): 0.11, Test Loss: 0.52, Test Correct Frac: 0.836
# Time: 3.63, Batch 2000, Train Loss (for batch): 0.16, Test Loss: 0.48, Test Correct Frac: 0.854
# Time: 3.62, Batch 2200, Train Loss (for batch): 0.34, Test Loss: 0.59, Test Correct Frac: 0.814
# Time: 3.66, Batch 2400, Train Loss (for batch): 0.08, Test Loss: 0.57, Test Correct Frac: 0.824
# Time: 3.65, Batch 2600, Train Loss (for batch): 0.15, Test Loss: 0.55, Test Correct Frac: 0.794
# ### EPOCH  1 ###
# Time: 2.11, Batch   0, Train Loss (for batch): 0.14, Test Loss: 0.54, Test Correct Frac: 0.814
# Time: 3.68, Batch 200, Train Loss (for batch): 0.23, Test Loss: 0.60, Test Correct Frac: 0.810
# Time: 3.67, Batch 400, Train Loss (for batch): 0.16, Test Loss: 0.49, Test Correct Frac: 0.843
# Time: 3.63, Batch 600, Train Loss (for batch): 0.18, Test Loss: 0.50, Test Correct Frac: 0.845
# Time: 3.66, Batch 800, Train Loss (for batch): 0.33, Test Loss: 0.55, Test Correct Frac: 0.836
# Time: 3.64, Batch 1000, Train Loss (for batch): 0.03, Test Loss: 0.45, Test Correct Frac: 0.848
# Time: 3.63, Batch 1200, Train Loss (for batch): 0.23, Test Loss: 0.45, Test Correct Frac: 0.854
# Time: 3.67, Batch 1400, Train Loss (for batch): 0.14, Test Loss: 0.42, Test Correct Frac: 0.860
# Time: 3.64, Batch 1600, Train Loss (for batch): 0.10, Test Loss: 0.51, Test Correct Frac: 0.823
# Time: 3.68, Batch 1800, Train Loss (for batch): 0.12, Test Loss: 0.40, Test Correct Frac: 0.861
# Time: 3.66, Batch 2000, Train Loss (for batch): 0.06, Test Loss: 0.42, Test Correct Frac: 0.855
# Time: 3.65, Batch 2200, Train Loss (for batch): 0.17, Test Loss: 0.42, Test Correct Frac: 0.863
# Time: 3.63, Batch 2400, Train Loss (for batch): 0.06, Test Loss: 0.43, Test Correct Frac: 0.875
# Time: 3.62, Batch 2600, Train Loss (for batch): 0.10, Test Loss: 0.44, Test Correct Frac: 0.875
# ### EPOCH  2 ###
# Time: 2.11, Batch   0, Train Loss (for batch): 0.06, Test Loss: 0.47, Test Correct Frac: 0.841
# Time: 3.68, Batch 200, Train Loss (for batch): 0.22, Test Loss: 0.61, Test Correct Frac: 0.810
# Time: 3.63, Batch 400, Train Loss (for batch): 1.72, Test Loss: 0.60, Test Correct Frac: 0.738
# Time: 3.66, Batch 600, Train Loss (for batch): 0.28, Test Loss: 0.74, Test Correct Frac: 0.795
# Time: 3.75, Batch 800, Train Loss (for batch): 0.24, Test Loss: 0.82, Test Correct Frac: 0.712
# Time: 3.81, Batch 1000, Train Loss (for batch): 0.12, Test Loss: 0.50, Test Correct Frac: 0.849
# Time: 3.96, Batch 1200, Train Loss (for batch): 0.62, Test Loss: 0.71, Test Correct Frac: 0.702
# Time: 3.68, Batch 1400, Train Loss (for batch): 0.13, Test Loss: 0.58, Test Correct Frac: 0.798
# Time: 3.72, Batch 1600, Train Loss (for batch): 0.17, Test Loss: 0.48, Test Correct Frac: 0.858
# Time: 3.66, Batch 1800, Train Loss (for batch): 0.18, Test Loss: 0.51, Test Correct Frac: 0.855
# Time: 3.69, Batch 2000, Train Loss (for batch): 0.10, Test Loss: 0.47, Test Correct Frac: 0.861
# Time: 3.63, Batch 2200, Train Loss (for batch): 0.12, Test Loss: 0.50, Test Correct Frac: 0.849
# Time: 3.62, Batch 2400, Train Loss (for batch): 0.19, Test Loss: 0.47, Test Correct Frac: 0.861
# Time: 3.59, Batch 2600, Train Loss (for batch): 0.16, Test Loss: 0.42, Test Correct Frac: 0.875
#
#
#  Net with  8 layers, 300 wide. Using learning rate of 0.001000 and 64 batches
#
#
#  Net with  8 layers, 500 wide. Using learning rate of 0.001000 and 64 batches
# ### EPOCH  0 ###
# Time: 2.07, Batch   0, Train Loss (for batch): 3.23, Test Loss: 0.91, Test Correct Frac: 0.625
# Time: 5.86, Batch 200, Train Loss (for batch): 0.55, Test Loss: 0.73, Test Correct Frac: 0.685
# Time: 5.83, Batch 400, Train Loss (for batch): 0.27, Test Loss: 0.68, Test Correct Frac: 0.723
# Time: 5.84, Batch 600, Train Loss (for batch): 0.66, Test Loss: 0.60, Test Correct Frac: 0.736
# Time: 6.72, Batch 800, Train Loss (for batch): 0.47, Test Loss: 0.85, Test Correct Frac: 0.607
# Time: 8.11, Batch 1000, Train Loss (for batch): 0.44, Test Loss: 0.67, Test Correct Frac: 0.729
# Time: 6.97, Batch 1200, Train Loss (for batch): 0.18, Test Loss: 0.64, Test Correct Frac: 0.738
# Time: 7.05, Batch 1400, Train Loss (for batch): 0.18, Test Loss: 0.63, Test Correct Frac: 0.784
# Time: 7.01, Batch 1600, Train Loss (for batch): 0.40, Test Loss: 0.57, Test Correct Frac: 0.806
# Time: 6.92, Batch 1800, Train Loss (for batch): 0.09, Test Loss: 0.50, Test Correct Frac: 0.852
# Time: 6.73, Batch 2000, Train Loss (for batch): 0.17, Test Loss: 0.52, Test Correct Frac: 0.846
# Time: 6.75, Batch 2200, Train Loss (for batch): 0.35, Test Loss: 0.60, Test Correct Frac: 0.791
# Time: 6.73, Batch 2400, Train Loss (for batch): 0.09, Test Loss: 0.48, Test Correct Frac: 0.860
# Time: 6.69, Batch 2600, Train Loss (for batch): 0.18, Test Loss: 0.56, Test Correct Frac: 0.739
# ### EPOCH  1 ###
# Time: 3.80, Batch   0, Train Loss (for batch): 0.18, Test Loss: 0.51, Test Correct Frac: 0.846
# Time: 6.72, Batch 200, Train Loss (for batch): 0.21, Test Loss: 0.58, Test Correct Frac: 0.826
# Time: 6.71, Batch 400, Train Loss (for batch): 0.18, Test Loss: 0.46, Test Correct Frac: 0.859
# Time: 6.75, Batch 600, Train Loss (for batch): 0.22, Test Loss: 0.49, Test Correct Frac: 0.859
# Time: 6.74, Batch 800, Train Loss (for batch): 0.32, Test Loss: 0.48, Test Correct Frac: 0.847
# Time: 6.69, Batch 1000, Train Loss (for batch): 0.07, Test Loss: 0.48, Test Correct Frac: 0.829
# Time: 6.68, Batch 1200, Train Loss (for batch): 0.21, Test Loss: 0.47, Test Correct Frac: 0.841
# Time: 6.75, Batch 1400, Train Loss (for batch): 0.44, Test Loss: 0.81, Test Correct Frac: 0.698
# Time: 6.75, Batch 1600, Train Loss (for batch): 0.40, Test Loss: 0.73, Test Correct Frac: 0.703
# Time: 6.99, Batch 1800, Train Loss (for batch): 0.25, Test Loss: 0.70, Test Correct Frac: 0.738
# Time: 6.86, Batch 2000, Train Loss (for batch): 0.35, Test Loss: 0.75, Test Correct Frac: 0.675
# Time: 7.10, Batch 2200, Train Loss (for batch): 0.36, Test Loss: 0.69, Test Correct Frac: 0.718
# Time: 6.86, Batch 2400, Train Loss (for batch): 0.18, Test Loss: 0.57, Test Correct Frac: 0.743
# Time: 6.85, Batch 2600, Train Loss (for batch): 0.16, Test Loss: 0.52, Test Correct Frac: 0.849
# ### EPOCH  2 ###
# Time: 3.86, Batch   0, Train Loss (for batch): 0.25, Test Loss: 0.51, Test Correct Frac: 0.801
# Time: 6.92, Batch 200, Train Loss (for batch): 0.19, Test Loss: 0.53, Test Correct Frac: 0.830
# Time: 6.83, Batch 400, Train Loss (for batch): 0.29, Test Loss: 0.56, Test Correct Frac: 0.813
# Time: 6.68, Batch 600, Train Loss (for batch): 0.20, Test Loss: 0.49, Test Correct Frac: 0.838
# Time: 6.68, Batch 800, Train Loss (for batch): 0.08, Test Loss: 0.47, Test Correct Frac: 0.847
# Time: 6.66, Batch 1000, Train Loss (for batch): 0.13, Test Loss: 0.40, Test Correct Frac: 0.879
# Time: 6.80, Batch 1200, Train Loss (for batch): 0.22, Test Loss: 0.46, Test Correct Frac: 0.857
# Time: 6.75, Batch 1400, Train Loss (for batch): 0.54, Test Loss: 0.91, Test Correct Frac: 0.681
# Time: 7.00, Batch 1600, Train Loss (for batch): 0.39, Test Loss: 0.78, Test Correct Frac: 0.671
# Time: 7.05, Batch 1800, Train Loss (for batch): 0.29, Test Loss: 0.64, Test Correct Frac: 0.744
# Time: 6.84, Batch 2000, Train Loss (for batch): 0.21, Test Loss: 0.64, Test Correct Frac: 0.747
# Time: 6.90, Batch 2200, Train Loss (for batch): 0.20, Test Loss: 0.57, Test Correct Frac: 0.742
# Time: 6.82, Batch 2400, Train Loss (for batch): 0.28, Test Loss: 0.56, Test Correct Frac: 0.745
# Time: 6.82, Batch 2600, Train Loss (for batch): 0.28, Test Loss: 0.58, Test Correct Frac: 0.742
#
#
#  Net with  8 layers, 500 wide. Using learning rate of 0.001000 and 64 batches

# %%
import pickle

# %%
with open("4_hyperparam_result_nets.pickle","wb") as f:
    pickle.dump(result_nets, f)

# %%
with open("4_hyperparam_result_params.pickle","wb") as f:
    pickle.dump((N_batchs, learning_rates, n_layers, layer_widths), f)

# %%
# Best resutls:
# Net with  5 layers, 500 wide. Using learning rate of 0.000100 and  4 batches
# Net with  8 layers, 300 wide. Using learning rate of 0.000100 and  4 batches
